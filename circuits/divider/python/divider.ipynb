# %% [markdown]
# ### Simple voltage divider

# %% [markdown]
# ### Imports

# %%
from pathlib import Path
import py4spice as spi

# %% [markdown]
# ### Dictionaries

# %%
netlists_dict: dict[str, spi.Netlist] = {}  # create empty netlist dictionary

# %% [markdown]
# ### Set up paths

# %%
proj_path = Path("/workspaces/learn_ngspicee/circuits/divider")
netlists_path: Path = proj_path / "netlists"
results_path: Path = proj_path / "sim_results"
results_path.mkdir(parents=True, exist_ok=True) # create results directory if it does not exist

ngspice_exe = Path("/usr/bin/ngspice") # ngspice executable
